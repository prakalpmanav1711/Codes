# %%
import pandas as pd

series1 = pd.Series(["BMW", "Toyota", "Honda"])
series2 = pd.Series(["Red", "Black", "Yellow"])
series1
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
dataFr = pd.DataFrame({"Car Name" : series1, "Car Color" : series2})
dataFr
# Out:
#   Car Name Car Color
# 0      BMW       Red
# 1   Toyota     Black
# 2    Honda    Yellow

# %%
datacar = pd.read_csv("car-sales.csv")
datacar
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
datacar.to_csv("exported.csv", index = False)
#ex = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")
#ex

# %%
datacar.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
datacar.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
datacar.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
datacar.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
datacar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
datacar.mean()
# Out:
# C:\Users\ratee\AppData\Local\Temp\ipykernel_17048\2077432257.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datacar.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
datacar["Doors"].sum()
# Out:
# 40

# %%
len(datacar)
# Out:
# 10

# %%
animals = pd.Series(["dog", "panda", "cat", "lion","tiger"], index = [1,3,2,5,3])
animals.loc[3]
# Out:
# 3    panda
# 3    tiger
# dtype: object

# %%
datacar.loc[4]
# Out:
# Make                Nissan
# Colour               White
# Odometer (KM)       213095
# Doors                    4
# Price            $3,500.00
# Name: 4, dtype: object

# %%
animals.iloc[:2]
# Out:
# 1      dog
# 3    panda
# dtype: object

# %%
animals.loc[:2]
# Out:
# 1      dog
# 3    panda
# 2      cat
# dtype: object

# %%
datacar[datacar["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
datacar[datacar["Odometer (KM)"]<100000]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(datacar["Make"],datacar["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
datacar.groupby(datacar["Make"]).mean()
# Out:
# C:\Users\ratee\AppData\Local\Temp\ipykernel_17048\1648687424.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   datacar.groupby(datacar["Make"]).mean()
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
datacar["Odometer (KM)"].plot()
# Out:
# <AxesSubplot: >

# %%
datacar.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'Odometer (KM)'}>,
#         <AxesSubplot: title={'center': 'Doors'}>]], dtype=object)

# %%
datacar["Price"] = datacar["Price"].str.removesuffix('.00').str.replace('[$\,\.]','').astype(int)
# Out:
# C:\Users\ratee\AppData\Local\Temp\ipykernel_17048\965978187.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   datacar["Price"] = datacar["Price"].str.removesuffix('.00').str.replace('[$\,\.]','').astype(int)

# %%
datacar["Make"] = datacar["Make"].str.lower()

# %%
datacar
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
datacar_missing = pd.read_csv("car-sales-missing-data.csv")
datacar_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
datacar_missing["Odometer"].fillna(datacar_missing["Odometer"].std(),inplace = True)

# %%
datacar_missing_dropped = datacar_missing.dropna(inplace = False)

# %%
datacar_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   76489.805168    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   76489.805168    4.0   $4,500
# 6   Honda    NaN   76489.805168    4.0   $7,500
# 7   Honda   Blue   76489.805168    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
datacar_missing_dropped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   76489.805168    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   76489.805168    4.0   $4,500

# %%
datacar["Fuel Economy"] = [5.4, 6.7, 8.2, 4.7, 6.8, 4.4, 2.3, 4.3, 1.1, 1.0]
datacar
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Fuel Economy
# 0  toyota  White         150043      4   4000           5.4
# 1   honda    Red          87899      4   5000           6.7
# 2  toyota   Blue          32549      3   7000           8.2
# 3     bmw  Black          11179      5  22000           4.7
# 4  nissan  White         213095      4   3500           6.8
# 5  toyota  Green          99213      4   4500           4.4
# 6   honda   Blue          45698      4   7500           2.3
# 7   honda   Blue          54738      4   7000           4.3
# 8  toyota  White          60000      4   6250           1.1
# 9  nissan  White          31600      4   9700           1.0

# %%
datacar["Fuel Used"] = (datacar["Odometer (KM)"]/100*datacar["Fuel Economy"])
datacar
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Fuel Economy  Fuel Used
# 0  toyota  White         150043      4   4000           5.4   8102.322
# 1   honda    Red          87899      4   5000           6.7   5889.233
# 2  toyota   Blue          32549      3   7000           8.2   2669.018
# 3     bmw  Black          11179      5  22000           4.7    525.413
# 4  nissan  White         213095      4   3500           6.8  14490.460
# 5  toyota  Green          99213      4   4500           4.4   4365.372
# 6   honda   Blue          45698      4   7500           2.3   1051.054
# 7   honda   Blue          54738      4   7000           4.3   2353.734
# 8  toyota  White          60000      4   6250           1.1    660.000
# 9  nissan  White          31600      4   9700           1.0    316.000

# %%
datacar.drop("Doors",axis = 1,inplace = True)
datacar
# Out:
#      Make Colour  Odometer (KM)  Price  Fuel Economy  Fuel Used
# 0  toyota  White         150043   4000           5.4   8102.322
# 1   honda    Red          87899   5000           6.7   5889.233
# 2  toyota   Blue          32549   7000           8.2   2669.018
# 3     bmw  Black          11179  22000           4.7    525.413
# 4  nissan  White         213095   3500           6.8  14490.460
# 5  toyota  Green          99213   4500           4.4   4365.372
# 6   honda   Blue          45698   7500           2.3   1051.054
# 7   honda   Blue          54738   7000           4.3   2353.734
# 8  toyota  White          60000   6250           1.1    660.000
# 9  nissan  White          31600   9700           1.0    316.000

# %%
sample = datacar.sample(frac = 0.2)
sample
# Out:
#      Make Colour  Odometer (KM)  Price  Fuel Economy  Fuel Used
# 0  toyota  White         150043   4000           5.4   8102.322
# 3     bmw  Black          11179  22000           4.7    525.413

# %%
shuffled = datacar.sample(frac = 1)
shuffled
# Out:
#      Make Colour  Odometer (KM)  Price  Fuel Economy  Fuel Used
# 3     bmw  Black          11179  22000           4.7    525.413
# 2  toyota   Blue          32549   7000           8.2   2669.018
# 5  toyota  Green          99213   4500           4.4   4365.372
# 9  nissan  White          31600   9700           1.0    316.000
# 7   honda   Blue          54738   7000           4.3   2353.734
# 1   honda    Red          87899   5000           6.7   5889.233
# 0  toyota  White         150043   4000           5.4   8102.322
# 6   honda   Blue          45698   7500           2.3   1051.054
# 8  toyota  White          60000   6250           1.1    660.000
# 4  nissan  White         213095   3500           6.8  14490.460

# %%
shuffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Price  Fuel Economy  Fuel Used
# 0      3     bmw  Black          11179  22000           4.7    525.413
# 1      2  toyota   Blue          32549   7000           8.2   2669.018
# 2      5  toyota  Green          99213   4500           4.4   4365.372
# 3      9  nissan  White          31600   9700           1.0    316.000
# 4      7   honda   Blue          54738   7000           4.3   2353.734
# 5      1   honda    Red          87899   5000           6.7   5889.233
# 6      0  toyota  White         150043   4000           5.4   8102.322
# 7      6   honda   Blue          45698   7500           2.3   1051.054
# 8      8  toyota  White          60000   6250           1.1    660.000
# 9      4  nissan  White         213095   3500           6.8  14490.460

# %%
shuffled["Odometer (KM)"] = shuffled["Odometer (KM)"].apply(lambda x:x/2.3)
shuffled
# Out:
#      Make Colour  Odometer (KM)  Price  Fuel Economy  Fuel Used
# 3     bmw  Black    4860.434783  22000           4.7    525.413
# 2  toyota   Blue   14151.739130   7000           8.2   2669.018
# 5  toyota  Green   43136.086957   4500           4.4   4365.372
# 9  nissan  White   13739.130435   9700           1.0    316.000
# 7   honda   Blue   23799.130435   7000           4.3   2353.734
# 1   honda    Red   38216.956522   5000           6.7   5889.233
# 0  toyota  White   65236.086957   4000           5.4   8102.322
# 6   honda   Blue   19868.695652   7500           2.3   1051.054
# 8  toyota  White   26086.956522   6250           1.1    660.000
# 4  nissan  White   92650.000000   3500           6.8  14490.460
