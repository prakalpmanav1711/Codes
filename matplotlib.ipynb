# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot([1,2,3,4,5,6,7,8,9]);

# %%
x = [1,2,3,4,5,6]
y = [1,4,9,16,25,36]
plt.plot(x,y);

# %%
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot()
# Out:
# []

# %%
fig, ax = plt.subplots()
plt.plot(x,y)

# %%
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %%
fig, ax = plt.subplots(figsize=(5,5))

# %%
ax.set(title ="Title", xlabel = "xLabel", ylabel = "yLabel")
ax.plot(x,y)
fig.savefig("plot.jpg")

# %%
x = np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig, ax = plt.subplots()
ax.set(title = "Title",xlabel = "xLabel",ylabel = "yLabel")
ax.plot(x,x**2)

# %%
fig, ax = plt.subplots()
ax.scatter(x,np.exp(x))

# %%
fig, ax = plt.subplots()
ax.scatter(x,np.sin(x))

# %%
nut_but_prices = {"Almond":10, "Peanut":8, "Cashew":12}
fig, ax = plt.subplots()
ax.bar(nut_but_prices.keys(),nut_but_prices.values())
# Out:
# <BarContainer object of 3 artists>

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_but_prices.keys()),list(nut_but_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
x = np.random.randn(1000)
x[:10]
# Out:
# array([ 0.50201853,  0.06620694, -0.2577109 , -1.22013753,  0.38997963,
#        -0.39759986,  1.07007651,  1.10075004,  0.06257326,  1.66633593])

# %%
fig, ax = plt.subplots()
ax.hist(x)
# Out:
# (array([  5.,  21.,  63., 128., 227., 248., 177.,  88.,  32.,  11.]),
#  array([-3.06602812, -2.46300319, -1.85997826, -1.25695333, -0.6539284 ,
#         -0.05090347,  0.55212146,  1.15514639,  1.75817132,  2.36119625,
#          2.96422119]),
#  <BarContainer object of 10 artists>)

# %%
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows = 2,ncols = 2, figsize = (5,5))
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(nut_but_prices.keys(),nut_but_prices.values())
ax4.hist(np.random.randn(1000))
# Out:
# (array([  7.,  36.,  82., 185., 230., 218., 158.,  60.,  18.,   6.]),
#  array([-2.97766421, -2.34719457, -1.71672494, -1.0862553 , -0.45578567,
#          0.17468397,  0.8051536 ,  1.43562324,  2.06609287,  2.69656251,
#          3.32703214]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(nrows = 2,ncols = 2, figsize = (5,5))
ax[0,0].plot(x,x/2)
ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].bar(nut_but_prices.keys(),nut_but_prices.values())
ax[1,1].hist(np.random.randn(1000))
# Out:
# (array([  6.,  41.,  85., 172., 227., 223., 145.,  80.,  14.,   7.]),
#  array([-2.91574714, -2.31652472, -1.7173023 , -1.11807988, -0.51885747,
#          0.08036495,  0.67958737,  1.27880979,  1.8780322 ,  2.47725462,
#          3.07647704]),
#  <BarContainer object of 10 artists>)

# %%
car_sales=  pd.read_csv("car-sales.csv")

# %%
ts = pd.Series(np.random.rand(1000), index = pd.date_range('1/1/2000',periods =1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot: >

# %%
car_sales["Sale Date"] = pd.date_range('1/1/2020', periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date
# 0  Toyota  White         150043      4   $4,000 2020-01-01
# 1   Honda    Red          87899      4   $5,000 2020-01-02
# 2  Toyota   Blue          32549      3   $7,000 2020-01-03
# 3     BMW  Black          11179      5  $22,000 2020-01-04
# 4  Nissan  White         213095      4   $3,500 2020-01-05
# 5  Toyota  Green          99213      4   $4,500 2020-01-06
# 6   Honda   Blue          45698      4   $7,500 2020-01-07
# 7   Honda   Blue          54738      4   $7,000 2020-01-08
# 8  Toyota  White          60000      4   $6,250 2020-01-09
# 9  Nissan  White          31600      4   $9,700 2020-01-10

# %%
car_sales["Price"] = car_sales["Price"].str.replace('$','')
car_sales
# Out:
# C:\Users\ratee\AppData\Local\Temp\ipykernel_11252\2223132354.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   car_sales["Price"] = car_sales["Price"].str.replace('$','')
#      Make Colour  Odometer (KM)  Doors   Price  Sale Date
# 0  Toyota  White         150043      4   4,000 2020-01-01
# 1   Honda    Red          87899      4   5,000 2020-01-02
# 2  Toyota   Blue          32549      3   7,000 2020-01-03
# 3     BMW  Black          11179      5  22,000 2020-01-04
# 4  Nissan  White         213095      4   3,500 2020-01-05
# 5  Toyota  Green          99213      4   4,500 2020-01-06
# 6   Honda   Blue          45698      4   7,500 2020-01-07
# 7   Honda   Blue          54738      4   7,000 2020-01-08
# 8  Toyota  White          60000      4   6,250 2020-01-09
# 9  Nissan  White          31600      4   9,700 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].str.replace(',','').astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4,000 2020-01-01         4000
# 1   Honda    Red          87899      4   5,000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7,000 2020-01-03        16000
# 3     BMW  Black          11179      5  22,000 2020-01-04        38000
# 4  Nissan  White         213095      4   3,500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4,500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7,500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7,000 2020-01-08        60500
# 8  Toyota  White          60000      4   6,250 2020-01-09        66750
# 9  Nissan  White          31600      4   9,700 2020-01-10        76450

# %%
car_sales.plot(x="Sale Date",y="Total Sales")
# Out:
# <AxesSubplot: xlabel='Sale Date'>

# %%
x = np.random.rand(10,4)
x
# Out:
# array([[0.04292657, 0.89260132, 0.77951685, 0.63197459],
#        [0.39808663, 0.06632163, 0.60686099, 0.64354231],
#        [0.49621346, 0.53910735, 0.68676861, 0.06087601],
#        [0.65502156, 0.23885827, 0.52261037, 0.44367377],
#        [0.6419801 , 0.74361499, 0.27183962, 0.58084898],
#        [0.92044524, 0.38185116, 0.35995889, 0.51151296],
#        [0.95725109, 0.19741239, 0.96448241, 0.77206922],
#        [0.48341282, 0.3087081 , 0.87780765, 0.13984255],
#        [0.27991577, 0.79055692, 0.15509395, 0.5996464 ],
#        [0.31823031, 0.48739328, 0.98962061, 0.37659266]])

# %%
df = pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.042927  0.892601  0.779517  0.631975
# 1  0.398087  0.066322  0.606861  0.643542
# 2  0.496213  0.539107  0.686769  0.060876
# 3  0.655022  0.238858  0.522610  0.443674
# 4  0.641980  0.743615  0.271840  0.580849
# 5  0.920445  0.381851  0.359959  0.511513
# 6  0.957251  0.197412  0.964482  0.772069
# 7  0.483413  0.308708  0.877808  0.139843
# 8  0.279916  0.790557  0.155094  0.599646
# 9  0.318230  0.487393  0.989621  0.376593

# %%
df.plot.bar()
# Out:
# <AxesSubplot: >

# %%
df.plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
car_sales.plot(x="Make",y="Odometer (KM)",kind="bar")
# Out:
# <AxesSubplot: xlabel='Make'>

# %%
car_sales["Odometer (KM)"].plot.hist(bins=400)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
car_sales.plot.hist(figsize=(10,5),subplots = True)
# Out:
# array([<AxesSubplot: ylabel='Frequency'>,
#        <AxesSubplot: ylabel='Frequency'>,
#        <AxesSubplot: ylabel='Frequency'>], dtype=object)

# %%
fig, ax = plt.subplots(figsize=(10,6))
temp = ax.scatter(x=car_sales["Doors"],y=car_sales["Total Sales"],c=car_sales["Odometer (KM)"])

# %%
ax.axhline(car_sales["Total Sales"].mean(), linestyle='--')

# %%
import pandas as pd
over_50 = pd.read_csv("heart-disease (1).csv")
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
fig,(ax0, ax1) = plt.subplots(nrows = 2, ncols = 1, figsize=(10,10))
scatter = ax0.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"])
ax0.set(title="Heart Disease and Cholesterol",xlabel="Age",ylabel="Cholesterol")
ax0.legend(*scatter.legend_elements(),title="Target")
ax0.axhline(y=over_50["chol"].mean(), linestyle="--")
scatter = ax1.scatter(x=over_50["age"],y=over_50["thalach"],c=over_50["target"])
ax1.set(title="Hear Disease and Max Heart Rate",xlabel="Age",ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(),title="Target")
ax1.axhline(y=over_50["thalach"].mean(),linestyle="--")

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4,000 2020-01-01         4000
# 1   Honda    Red          87899      4   5,000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7,000 2020-01-03        16000
# 3     BMW  Black          11179      5  22,000 2020-01-04        38000
# 4  Nissan  White         213095      4   3,500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4,500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7,500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7,000 2020-01-08        60500
# 8  Toyota  White          60000      4   6,250 2020-01-09        66750
# 9  Nissan  White          31600      4   9,700 2020-01-10        76450

# %%
car_sales.plot()
# Out:
# <AxesSubplot: >

# %%
plt.style.use('seaborn-whitegrid')
# Out:
# C:\Users\ratee\AppData\Local\Temp\ipykernel_11252\2414357448.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
car_sales.plot()
# Out:
# <AxesSubplot: >

# %%
df = pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.042927  0.892601  0.779517  0.631975
# 1  0.398087  0.066322  0.606861  0.643542
# 2  0.496213  0.539107  0.686769  0.060876
# 3  0.655022  0.238858  0.522610  0.443674
# 4  0.641980  0.743615  0.271840  0.580849
# 5  0.920445  0.381851  0.359959  0.511513
# 6  0.957251  0.197412  0.964482  0.772069
# 7  0.483413  0.308708  0.877808  0.139843
# 8  0.279916  0.790557  0.155094  0.599646
# 9  0.318230  0.487393  0.989621  0.376593

# %%
plt.style.use('ggplot')
ax = df.plot(kind="bar")
ax.set(title="Heading",xlabel="X",ylabel="Y")
ax.legend().set_visible(True)
